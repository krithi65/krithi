# %%
#install packages python and mongo db
# !pip install dnspython
# !pip install pymongo[srv]
# Out:
# Collecting dnspython
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      |████████████████████████████████| 269 kB 8.7 MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-2.2.1
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.1.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)

# %%
# making a connection to mongo db
import pymongo
import re
client= pymongo.MongoClient("mongodb+srv://krithi:krithi@cluster0.5r88k.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db=client.details
records=db.mail

# %%
# validate user details-name,phone number length is equal to 10
#email is validated with special character @ and .com in between
#through TRY and Exception

regex="^[a-zA-Z0-9-_]+@[a-zA-Z0-9]+.[a-z]{1,3}$"
a=int(input())
for i in range(a):
  name=list(input("enter name:").split())
  l=[]
  for x in name:
      l.append(x.capitalize())
  name=" ".join(l)
  phone=input("enter your number:")
  while len(phone)!=10 :
    phone=input("enter valid no")
  email=input("enter email")
  while not re.fullmatch(regex,email):
    email=input("enter valid")
  d = {
     "name1":name,
     "ph":phone,
     "mail":email
  }
  try:
    records.insert_one(d)  
    print("data inserted")
  except:
    print("failed")
# Out:
# 2
# enter name:kiki
# enter your number:9003235432
# enter emailkkii@gmail.com
# data inserted
# enter name:amu
# enter your number:9885656435
# enter emailarumyar@gmail.com
# data inserted

# %%
#find data through NOSQL query
print(records.find_one())
# Out:
# {'_id': ObjectId('6257ccf8c830942586147ed2'), 'name1': 'Krithi', 'ph': '9003232324', 'mail': 'amukutty@gmail.com'}

# %%
#display details in data frame in Pandas
import pandas as pd
for x in records.find():
   df= pd.DataFrame(x,index=["1"])
df
# Out:
#                         _id name1          ph               mail
# 1  6257d1ca14943674c60f1e38   Amu  9885656435  arumyar@gmail.com
